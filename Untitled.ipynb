# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import streamlit as st

import warnings
warnings.filterwarnings('ignore', category=UserWarning, message="missing ScriptRunContext!")


# Load dataset
salary_dataset = pd.read_csv('C:/Users/naruk/OneDrive/Desktop/python/Salary Data.csv')


# Data preprocessing
salary_dataset.dropna(inplace=True)
salary_dataset['Salary'] = pd.to_numeric(salary_dataset['Salary'], errors='coerce')
salary_dataset['Years of Experience'] = pd.to_numeric(salary_dataset['Years of Experience'], errors='coerce')
salary_dataset['Age'] = pd.to_numeric(salary_dataset['Age'], errors='coerce')
salary_dataset.drop_duplicates(inplace=True)
salary_dataset.reset_index(inplace=True, drop=True)

# Encoding categorical variables
salary_dataset.replace({'Education Level': {"Bachelor's": 0, "Master's": 1, "PhD": 2}}, inplace=True)

salary_dataset['Education Level'] = salary_dataset['Education Level'].replace(
    {"Bachelor's": 0, "Master's": 1, "PhD": 2}
).astype(int)  # Ensure explicit casting


# Main Application
st.title("PayVision: Salary Insights and Prediction App")

# Create a single-page layout with sections using divs and spans
with st.container():
    st.markdown("""<div style='padding: 20px; border: 1px solid #ddd; border-radius: 8px;'>""", unsafe_allow_html=True)
    st.header("Data Overview and Insights")
    
    col1, col2 = st.columns(2)

    with col1:
        st.subheader("Dataset Snapshot")
        st.write(salary_dataset.head())

    with col2:
        st.subheader("Summary Statistics")
        st.write(salary_dataset.describe())
        st.write(f"*Number of Duplicates:* {salary_dataset.duplicated().sum()}")

    st.markdown("</div>", unsafe_allow_html=True)

with st.container():
    st.markdown("""<div style='padding: 20px; margin-top: 20px; border: 1px solid #ddd; border-radius: 8px;'>""", unsafe_allow_html=True)
    st.header("Visualizations")
    
    # Visualizations for Salary Insights
    st.subheader("Salary Insights by Gender and Education Level")
    
    col1, col2 = st.columns(2)

    with col1:
        salary_by_gender = salary_dataset.groupby("Gender")["Salary"].mean()
        fig = px.bar(x=salary_by_gender.index, y=salary_by_gender.values, 
                     labels={'x': 'Gender', 'y': 'Mean Salary'}, title='Mean Salary by Gender')
        st.plotly_chart(fig)

    with col2:
        salary_by_level = salary_dataset.groupby("Education Level")["Salary"].mean()
        fig = px.bar(x=salary_by_level.index.map({0: "Bachelor's", 1: "Master's", 2: "PhD"}), 
                     y=salary_by_level.values, labels={'x': 'Education Level', 'y': 'Mean Salary'},
                     title='Mean Salary by Education Level')
        st.plotly_chart(fig)

    # Visualizations for Years of Experience and Age Groups
    st.subheader("Salary Insights by Years of Experience and Age Groups")
    
    col1, col2 = st.columns(2)

    with col1:
        def groupping_exp(exp):
            if exp <= 5:
                return "0-5 years"
            elif exp <= 10:
                return "6-10 years"
            elif exp <= 15:
                return "11-15 years"
            elif exp <= 20:
                return "16-20 years"
            else:
                return "20+"

        salary_by_exp = salary_dataset.groupby(salary_dataset["Years of Experience"].apply(groupping_exp))["Salary"].mean()
        fig = px.bar(x=salary_by_exp.index, y=salary_by_exp.values, 
                     labels={'x': 'Years of Experience', 'y': 'Mean Salary'},
                     title='Mean Salary by Years of Experience')
        st.plotly_chart(fig)

    with col2:
        def groupping_age(age):
            if age >= 20 and age <= 25:
                return "20-25 years"
            elif age <= 30:
                return "25-30 years"
            elif age <= 35:
                return "30-35 years"
            elif age <= 40:
                return "35-40 years"
            elif age <= 45:
                return "40-45 years"
            elif age <= 50:
                return "45-50 years"
            else:
                return "50+"

        salary_by_age = salary_dataset.groupby(salary_dataset["Age"].apply(groupping_age))["Salary"].mean()
        fig = px.bar(x=salary_by_age.index, y=salary_by_age.values, 
                     labels={'x': 'Age Groups', 'y': 'Mean Salary'},
                     title='Mean Salary by Age Groups')
        st.plotly_chart(fig)

    st.markdown("</div>", unsafe_allow_html=True)

with st.container():
    st.markdown("""<div style='padding: 20px; margin-top: 20px; border: 1px solid #ddd; border-radius: 8px;'>""", unsafe_allow_html=True)
    st.header("Model Training and Prediction")

    # Feature selection
    X = salary_dataset.drop(['Gender', 'Job Title', 'Salary'], axis=1)
    Y = salary_dataset['Salary']

    # Split data
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=10)

    # Train model
    with st.spinner('Training Linear Regression Model...'):
        lin_model = LinearRegression()
        lin_model.fit(X_train, Y_train)
    st.success('Model Training Complete!')

    # Evaluate model
    training_data_predict = lin_model.predict(X_train)
    error_score = metrics.r2_score(Y_train, training_data_predict)
    st.metric("Training R-Squared Error", f"{error_score:.2f}")

    test_data_predict = lin_model.predict(X_test)
    test_error_score = metrics.r2_score(Y_test, test_data_predict)
    st.metric("Test R-Squared Error", f"{test_error_score:.2f}")

    # Visualize results
    col1, col2 = st.columns(2)
    with col1:
        st.write("### Actual vs Predicted (Training Data)")
        fig, ax = plt.subplots()
        plt.scatter(Y_train, training_data_predict)
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.title("Actual vs Predicted Salary (Training)")
        st.pyplot(fig)

    with col2:
        st.write("### Actual vs Predicted (Test Data)")
        fig, ax = plt.subplots()
        plt.scatter(Y_test, test_data_predict)
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.title("Actual vs Predicted Salary (Test)")
        st.pyplot(fig)

    st.subheader("Predict Salary")

    # Input for prediction
    years_experience = st.number_input("Years of Experience", min_value=0, value=0)
    education_level = st.selectbox("Education Level", ["Bachelor's", "Master's", "PhD"])
    age = st.number_input("Age", min_value=18, value=25)

    # Convert inputs and predict
    education_map = {"Bachelor's": 0, "Master's": 1, "PhD": 2}
    user_data = pd.DataFrame({
        'Years of Experience': [years_experience],
        'Education Level': [education_map[education_level]],
        'Age': [age]
    })

    # Ensure that user_data columns are in the same order as X_train columns
    user_data = user_data[X_train.columns]

    if st.button("Predict Salary"):
        predicted_salary = lin_model.predict(user_data)
        st.write(f"Predicted Salary: ${predicted_salary[0]:,.2f}")

    st.markdown("</div>", unsafe_allow_html=True)
# Out:
# C:\Users\naruk\AppData\Local\Temp\ipykernel_16248\1479215371.py:28: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# 2024-12-16 00:31:32.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:32.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:33.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 00:31:34.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
